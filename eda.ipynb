# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/train.csv')

# %%
df.head()
# Out:
#    id  annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0   0       29367.99                 0.084           736      2528.42
# 1   1       22108.02                 0.166           636      4593.10
# 2   2       49566.20                 0.097           694     17005.15
# 3   3       46858.25                 0.065           533      4682.48
# 4   4       25496.70                 0.053           665     12184.43
#
#    interest_rate  gender marital_status education_level employment_status  \
# 0          13.67  Female         Single     High School     Self-employed
# 1          12.92    Male        Married        Master's          Employed
# 2           9.76    Male         Single     High School          Employed
# 3          16.10  Female         Single     High School          Employed
# 4          10.21    Male        Married     High School          Employed
#
#          loan_purpose grade_subgrade  loan_paid_back
# 0               Other             C3             1.0
# 1  Debt consolidation             D3             0.0
# 2  Debt consolidation             C5             1.0
# 3  Debt consolidation             F1             1.0
# 4               Other             D1             1.0

# %%
# Nie ma nulli 
df.isnull().sum()
# Out:
# id                      0
# annual_income           0
# debt_to_income_ratio    0
# credit_score            0
# loan_amount             0
# interest_rate           0
# gender                  0
# marital_status          0
# education_level         0
# employment_status       0
# loan_purpose            0
# grade_subgrade          0
# loan_paid_back          0
# dtype: int64

# %%
# ~80% jest spłaconych kredytów, jest niezrównowazenie międzi spłaconymi i nie
df['loan_paid_back'].value_counts(normalize=True)
# Out:
# loan_paid_back
# 1.0    0.79882
# 0.0    0.20118
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593994 entries, 0 to 593993
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    593994 non-null  int64
#  1   annual_income         593994 non-null  float64
#  2   debt_to_income_ratio  593994 non-null  float64
#  3   credit_score          593994 non-null  int64
#  4   loan_amount           593994 non-null  float64
#  5   interest_rate         593994 non-null  float64
#  6   gender                593994 non-null  object
#  7   marital_status        593994 non-null  object
#  8   education_level       593994 non-null  object
#  9   employment_status     593994 non-null  object
#  10  loan_purpose          593994 non-null  object
#  11  grade_subgrade        593994 non-null  object
#  12  loan_paid_back        593994 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 58.9+ MB

# %%
df.nunique()
# Out:
# id                      593994
# annual_income           119728
# debt_to_income_ratio       526
# credit_score               399
# loan_amount             111570
# interest_rate             1454
# gender                       3
# marital_status               4
# education_level              5
# employment_status            5
# loan_purpose                 8
# grade_subgrade              30
# loan_paid_back               2
# dtype: int64

# %%
cat_col = df.select_dtypes(include='object').columns.tolist()
num_col = df.select_dtypes(include='number').columns.tolist()

# %%
num_col
# Out:
# ['id',
#  'annual_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate',
#  'loan_paid_back']

# %%
df[cat_col].nunique()
# Out:
# gender                3
# marital_status        4
# education_level       5
# employment_status     5
# loan_purpose          8
# grade_subgrade       30
# dtype: int64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# gender
# Female    0.515451
# Male      0.478273
# Other     0.006276
# Name: proportion, dtype: float64

# %%
df['marital_status'].value_counts()
# Out:
# marital_status
# Single      288843
# Married     277239
# Divorced     21312
# Widowed       6600
# Name: count, dtype: int64

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Bachelor's     279606
# High School    183592
# Master's        93097
# Other           26677
# PhD             11022
# Name: count, dtype: int64

# %%
df['employment_status'].value_counts()
# Out:
# employment_status
# Employed         450645
# Unemployed        62485
# Self-employed     52480
# Retired           16453
# Student           11931
# Name: count, dtype: int64

# %%
df['loan_purpose'].value_counts()
# Out:
# loan_purpose
# Debt consolidation    324695
# Other                  63874
# Car                    58108
# Home                   44118
# Education              36641
# Business               35303
# Medical                22806
# Vacation                8449
# Name: count, dtype: int64

# %%
df['grade_subgrade'].value_counts()
# Out:
# grade_subgrade
# C3    58695
# C4    55957
# C2    54443
# C1    53363
# C5    53317
# D1    37029
# D3    36694
# D4    35097
# D2    34432
# D5    32101
# B2    15167
# B1    14344
# B5    13937
# B3    13926
# B4    13877
# E4     8036
# E3     7075
# E1     6891
# E2     6372
# E5     6084
# F5     5947
# F4     5535
# F1     5534
# F2     5203
# F3     5082
# A5     2471
# A3     2066
# A2     2018
# A4     1701
# A1     1600
# Name: count, dtype: int64

# %%
df_ex = df.copy()
df_ex['grade_letter'] = df['grade_subgrade'].str[0]
df_ex['subgrade_num'] = df['grade_subgrade'].str[1:].astype(int)

# %%
del df_ex['id']

# %%
del df_ex['grade_subgrade']

# %%
df_ex
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0            29367.99                 0.084           736      2528.42
# 1            22108.02                 0.166           636      4593.10
# 2            49566.20                 0.097           694     17005.15
# 3            46858.25                 0.065           533      4682.48
# 4            25496.70                 0.053           665     12184.43
# ...               ...                   ...           ...          ...
# 593989       23004.26                 0.152           703     20958.37
# 593990       35289.43                 0.105           559      3257.24
# 593991       47112.64                 0.072           675       929.27
# 593992       76748.44                 0.067           740     16290.40
# 593993       48959.52                 0.096           752      7707.73
#
#         interest_rate  gender marital_status education_level  \
# 0               13.67  Female         Single     High School
# 1               12.92    Male        Married        Master's
# 2                9.76    Male         Single     High School
# 3               16.10  Female         Single     High School
# 4               10.21    Male        Married     High School
# ...               ...     ...            ...             ...
# 593989          10.92  Female         Single     High School
# 593990          14.62    Male         Single      Bachelor's
# 593991          14.13  Female        Married      Bachelor's
# 593992           9.87    Male         Single      Bachelor's
# 593993          10.31    Male        Married     High School
#
#        employment_status        loan_purpose  loan_paid_back grade_letter  \
# 0          Self-employed               Other             1.0            C
# 1               Employed  Debt consolidation             0.0            D
# 2               Employed  Debt consolidation             1.0            C
# 3               Employed  Debt consolidation             1.0            F
# 4               Employed               Other             1.0            D
# ...                  ...                 ...             ...          ...
# 593989          Employed            Business             1.0            C
# 593990          Employed  Debt consolidation             1.0            F
# 593991          Employed  Debt consolidation             1.0            C
# 593992          Employed  Debt consolidation             1.0            B
# 593993          Employed           Education             1.0            B
#
#         subgrade_num
# 0                  3
# 1                  3
# 2                  5
# 3                  1
# 4                  1
# ...              ...
# 593989             3
# 593990             5
# 593991             1
# 593992             2
# 593993             3
#
# [593994 rows x 13 columns]

# %%
grade_map = {'A':1, 'B':2, 'C':3, 'D':4, 'E':5, 'F':6}
df_ex['grade_letter_rank'] = df_ex['grade_letter'].map(grade_map)

# %%
del df_ex['grade_letter']

# %%
df_ex
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0            29367.99                 0.084           736      2528.42
# 1            22108.02                 0.166           636      4593.10
# 2            49566.20                 0.097           694     17005.15
# 3            46858.25                 0.065           533      4682.48
# 4            25496.70                 0.053           665     12184.43
# ...               ...                   ...           ...          ...
# 593989       23004.26                 0.152           703     20958.37
# 593990       35289.43                 0.105           559      3257.24
# 593991       47112.64                 0.072           675       929.27
# 593992       76748.44                 0.067           740     16290.40
# 593993       48959.52                 0.096           752      7707.73
#
#         interest_rate  gender marital_status education_level  \
# 0               13.67  Female         Single     High School
# 1               12.92    Male        Married        Master's
# 2                9.76    Male         Single     High School
# 3               16.10  Female         Single     High School
# 4               10.21    Male        Married     High School
# ...               ...     ...            ...             ...
# 593989          10.92  Female         Single     High School
# 593990          14.62    Male         Single      Bachelor's
# 593991          14.13  Female        Married      Bachelor's
# 593992           9.87    Male         Single      Bachelor's
# 593993          10.31    Male        Married     High School
#
#        employment_status        loan_purpose  loan_paid_back  subgrade_num  \
# 0          Self-employed               Other             1.0             3
# 1               Employed  Debt consolidation             0.0             3
# 2               Employed  Debt consolidation             1.0             5
# 3               Employed  Debt consolidation             1.0             1
# 4               Employed               Other             1.0             1
# ...                  ...                 ...             ...           ...
# 593989          Employed            Business             1.0             3
# 593990          Employed  Debt consolidation             1.0             5
# 593991          Employed  Debt consolidation             1.0             1
# 593992          Employed  Debt consolidation             1.0             2
# 593993          Employed           Education             1.0             3
#
#         grade_letter_rank
# 0                       3
# 1                       4
# 2                       3
# 3                       6
# 4                       4
# ...                   ...
# 593989                  3
# 593990                  6
# 593991                  3
# 593992                  2
# 593993                  2
#
# [593994 rows x 13 columns]

# %%
df_ex['education_level'].value_counts()
# Out:
# education_level
# Bachelor's     279606
# High School    183592
# Master's        93097
# Other           26677
# PhD             11022
# Name: count, dtype: int64

# %%
education_ranking = {"PhD": 5, "Master's": 4, "Bachelor's": 3, "High School": 2, "Other": 1}
df_ex['education_rank'] = df_ex['education_level'].map(education_ranking)

# %%
del df_ex['education_level']

# %%
df_ex
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0            29367.99                 0.084           736      2528.42
# 1            22108.02                 0.166           636      4593.10
# 2            49566.20                 0.097           694     17005.15
# 3            46858.25                 0.065           533      4682.48
# 4            25496.70                 0.053           665     12184.43
# ...               ...                   ...           ...          ...
# 593989       23004.26                 0.152           703     20958.37
# 593990       35289.43                 0.105           559      3257.24
# 593991       47112.64                 0.072           675       929.27
# 593992       76748.44                 0.067           740     16290.40
# 593993       48959.52                 0.096           752      7707.73
#
#         interest_rate  gender marital_status employment_status  \
# 0               13.67  Female         Single     Self-employed
# 1               12.92    Male        Married          Employed
# 2                9.76    Male         Single          Employed
# 3               16.10  Female         Single          Employed
# 4               10.21    Male        Married          Employed
# ...               ...     ...            ...               ...
# 593989          10.92  Female         Single          Employed
# 593990          14.62    Male         Single          Employed
# 593991          14.13  Female        Married          Employed
# 593992           9.87    Male         Single          Employed
# 593993          10.31    Male        Married          Employed
#
#               loan_purpose  loan_paid_back  subgrade_num  grade_letter_rank  \
# 0                    Other             1.0             3                  3
# 1       Debt consolidation             0.0             3                  4
# 2       Debt consolidation             1.0             5                  3
# 3       Debt consolidation             1.0             1                  6
# 4                    Other             1.0             1                  4
# ...                    ...             ...           ...                ...
# 593989            Business             1.0             3                  3
# 593990  Debt consolidation             1.0             5                  6
# 593991  Debt consolidation             1.0             1                  3
# 593992  Debt consolidation             1.0             2                  2
# 593993           Education             1.0             3                  2
#
#         education_rank
# 0                    2
# 1                    4
# 2                    2
# 3                    2
# 4                    2
# ...                ...
# 593989               2
# 593990               3
# 593991               3
# 593992               3
# 593993               2
#
# [593994 rows x 13 columns]

# %%
df_ex = pd.get_dummies(df_ex, columns=['gender', 'marital_status', 'employment_status', 'loan_purpose'], drop_first=True)

# %%
df_ex
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0            29367.99                 0.084           736      2528.42
# 1            22108.02                 0.166           636      4593.10
# 2            49566.20                 0.097           694     17005.15
# 3            46858.25                 0.065           533      4682.48
# 4            25496.70                 0.053           665     12184.43
# ...               ...                   ...           ...          ...
# 593989       23004.26                 0.152           703     20958.37
# 593990       35289.43                 0.105           559      3257.24
# 593991       47112.64                 0.072           675       929.27
# 593992       76748.44                 0.067           740     16290.40
# 593993       48959.52                 0.096           752      7707.73
#
#         interest_rate  loan_paid_back  subgrade_num  grade_letter_rank  \
# 0               13.67             1.0             3                  3
# 1               12.92             0.0             3                  4
# 2                9.76             1.0             5                  3
# 3               16.10             1.0             1                  6
# 4               10.21             1.0             1                  4
# ...               ...             ...           ...                ...
# 593989          10.92             1.0             3                  3
# 593990          14.62             1.0             5                  6
# 593991          14.13             1.0             1                  3
# 593992           9.87             1.0             2                  2
# 593993          10.31             1.0             3                  2
#
#         education_rank  gender_Male  ...  employment_status_Self-employed  \
# 0                    2        False  ...                             True
# 1                    4         True  ...                            False
# 2                    2         True  ...                            False
# 3                    2        False  ...                            False
# 4                    2         True  ...                            False
# ...                ...          ...  ...                              ...
# 593989               2        False  ...                            False
# 593990               3         True  ...                            False
# 593991               3        False  ...                            False
# 593992               3         True  ...                            False
# 593993               2         True  ...                            False
#
#         employment_status_Student  employment_status_Unemployed  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                           False                         False
# ...                           ...                           ...
# 593989                      False                         False
# 593990                      False                         False
# 593991                      False                         False
# 593992                      False                         False
# 593993                      False                         False
#
#         loan_purpose_Car  loan_purpose_Debt consolidation  \
# 0                  False                            False
# 1                  False                             True
# 2                  False                             True
# 3                  False                             True
# 4                  False                            False
# ...                  ...                              ...
# 593989             False                            False
# 593990             False                             True
# 593991             False                             True
# 593992             False                             True
# 593993             False                            False
#
#         loan_purpose_Education  loan_purpose_Home  loan_purpose_Medical  \
# 0                        False              False                 False
# 1                        False              False                 False
# 2                        False              False                 False
# 3                        False              False                 False
# 4                        False              False                 False
# ...                        ...                ...                   ...
# 593989                   False              False                 False
# 593990                   False              False                 False
# 593991                   False              False                 False
# 593992                   False              False                 False
# 593993                    True              False                 False
#
#         loan_purpose_Other  loan_purpose_Vacation
# 0                     True                  False
# 1                    False                  False
# 2                    False                  False
# 3                    False                  False
# 4                     True                  False
# ...                    ...                    ...
# 593989               False                  False
# 593990               False                  False
# 593991               False                  False
# 593992               False                  False
# 593993               False                  False
#
# [593994 rows x 25 columns]

# %%
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score

X = df_ex.drop(['loan_paid_back'], axis=1)
y = df_ex['loan_paid_back']

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
oof_preds = np.zeros(len(X))
models = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)
    dval = xgb.DMatrix(X_val, label=y_val, enable_categorical=True)
    
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'tree_method': 'hist', 
        'learning_rate': 0.05,
        'max_depth': 6,  
        'subsample': 0.8, 
        'colsample_bytree': 0.8,    
        'random_state': 42
    }
    
    model = xgb.train(
        params,
        dtrain,
        num_boost_round=1000,
        evals=[(dtrain, 'train'), (dval, 'valid')],
        early_stopping_rounds=50,
        verbose_eval=100
    )

    oof_preds[val_idx] = model.predict(dval)
    models.append(model)
    
    print(f"Fold {fold+1} AUC: {roc_auc_score(y_val, oof_preds[val_idx]):.4f}")

print(f"\nOverall CV AUC Score: {roc_auc_score(y, oof_preds):.4f}")
# Out:
# [0]	train-auc:0.86427	valid-auc:0.86500
# [100]	train-auc:0.91713	valid-auc:0.91761
# [200]	train-auc:0.92081	valid-auc:0.91950
# [300]	train-auc:0.92374	valid-auc:0.92061
# [400]	train-auc:0.92632	valid-auc:0.92139
# [500]	train-auc:0.92860	valid-auc:0.92195
# [600]	train-auc:0.93056	valid-auc:0.92230
# [700]	train-auc:0.93228	valid-auc:0.92250
# [800]	train-auc:0.93394	valid-auc:0.92261
# [844]	train-auc:0.93466	valid-auc:0.92259
# Fold 1 AUC: 0.9226
# [0]	train-auc:0.86446	valid-auc:0.86431
# [100]	train-auc:0.91743	valid-auc:0.91684
# [200]	train-auc:0.92090	valid-auc:0.91873
# [300]	train-auc:0.92395	valid-auc:0.92014
# [400]	train-auc:0.92641	valid-auc:0.92092
# [500]	train-auc:0.92861	valid-auc:0.92150
# [600]	train-auc:0.93049	valid-auc:0.92190
# [700]	train-auc:0.93228	valid-auc:0.92217
# [800]	train-auc:0.93382	valid-auc:0.92228
# [900]	train-auc:0.93526	valid-auc:0.92231
# Fold 2 AUC: 0.9223
# [0]	train-auc:0.86444	valid-auc:0.86444
# [100]	train-auc:0.91764	valid-auc:0.91548
# [200]	train-auc:0.92117	valid-auc:0.91723
# [300]	train-auc:0.92410	valid-auc:0.91837
# [400]	train-auc:0.92672	valid-auc:0.91931
# [500]	train-auc:0.92891	valid-auc:0.91989
# [600]	train-auc:0.93076	valid-auc:0.92025
# [700]	train-auc:0.93260	valid-auc:0.92046
# [800]	train-auc:0.93415	valid-auc:0.92055
# [831]	train-auc:0.93462	valid-auc:0.92054
# Fold 3 AUC: 0.9205
# [0]	train-auc:0.86488	valid-auc:0.86278
# [100]	train-auc:0.91750	valid-auc:0.91640
# [200]	train-auc:0.92100	valid-auc:0.91825
# [300]	train-auc:0.92398	valid-auc:0.91943
# [400]	train-auc:0.92656	valid-auc:0.92022
# [500]	train-auc:0.92881	valid-auc:0.92077
# [600]	train-auc:0.93077	valid-auc:0.92119
# [700]	train-auc:0.93257	valid-auc:0.92137
# [800]	train-auc:0.93424	valid-auc:0.92151
# [834]	train-auc:0.93479	valid-auc:0.92151
# Fold 4 AUC: 0.9215
# [0]	train-auc:0.86418	valid-auc:0.86496
# [100]	train-auc:0.91746	valid-auc:0.91598
# [200]	train-auc:0.92088	valid-auc:0.91777
# [300]	train-auc:0.92394	valid-auc:0.91909
# [400]	train-auc:0.92647	valid-auc:0.91986
# [500]	train-auc:0.92871	valid-auc:0.92042
# [600]	train-auc:0.93065	valid-auc:0.92075
# [700]	train-auc:0.93234	valid-auc:0.92089
# [800]	train-auc:0.93389	valid-auc:0.92100
# [900]	train-auc:0.93543	valid-auc:0.92104
# [905]	train-auc:0.93551	valid-auc:0.92104
# Fold 5 AUC: 0.9210
#
# Overall CV AUC Score: 0.9216

# %%
model.save_model('loan_repayment_model_day1.json')
